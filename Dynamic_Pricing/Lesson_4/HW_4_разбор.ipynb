# %%
# 1 Загрузите данные в соответсвующие датафреймы

# %%
# 2 Для каждого набора данных '*_group_sku.csv' посчитайте кол-во уникальных "vendor" и "brand"
# Результат сохраните в виде file | vendor_unique_number | brand_unique_number

# %%
import pandas as pd
import numpy as np

# %%
#import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

# %%
first_group = pd.read_csv('first_group_sku.csv')
second_group = pd.read_csv('second_group_sku.csv')
third_group = pd.read_csv('third_group_sku.csv')
sku_dict = pd.read_csv('sku_dict.csv')
promo_df = pd.read_csv('promo_1510002.csv')
conc_df = pd.read_csv('conc_df.csv')

# %%
print(first_group.merge(sku_dict[['sku_id', 'vendor', 'brand_code']]
                  .rename(columns={'sku_id':'SKU'}), how='left', on='SKU').vendor.nunique())
print(first_group.merge(sku_dict[['sku_id', 'vendor', 'brand_code']]
                  .rename(columns={'sku_id':'SKU'}), how='left', on='SKU').brand_code.nunique())
# Out:
# 2
# 1

# %%
print(second_group.merge(sku_dict[['sku_id', 'vendor', 'brand_code']]
                  .rename(columns={'sku_id':'SKU'}), how='left', on='SKU').vendor.nunique())
print(second_group.merge(sku_dict[['sku_id', 'vendor', 'brand_code']]
                  .rename(columns={'sku_id':'SKU'}), how='left', on='SKU').brand_code.nunique())
# Out:
# 9
# 1

# %%
print(third_group.merge(sku_dict[['sku_id', 'vendor', 'brand_code']]
                  .rename(columns={'sku_id':'SKU'}), how='left', on='SKU').vendor.nunique())
print(third_group.merge(sku_dict[['sku_id', 'vendor', 'brand_code']]
                  .rename(columns={'sku_id':'SKU'}), how='left', on='SKU').brand_code.nunique())
# Out:
# 8
# 1

# %%
pd.DataFrame({'file':['first_group.csv', 'second_group.csv', 'third_group.csv']
              , 'vendor_unique_number':[2,9,8], 'brand_unique_number':[1,1,1]}).to_csv('answer_list_1_1.csv'
                                                                                       , index=None)

# %%
# 3 Для каждой из групп найдите максимальную и минимульную цену для каждого SKU
# Результат сохраните в виде  SKU | min_price | max_price

# %%
agg_1 = first_group.groupby('SKU').price_per_sku.agg(['min','max']).reset_index()

# %%
agg_2 = second_group.groupby('SKU').price_per_sku.agg(['min','max']).reset_index()

# %%
agg_3 = third_group.groupby('SKU').price_per_sku.agg(['min','max']).reset_index()

# %%
pd.concat([agg_1,agg_2,agg_3]).to_csv('answer_list_1_2.csv', index=None)

# %%
# 4 Для первой группы данных постройте зависимости цены от времени
# Посчитайте кол-во пропусков в цене на каждое SKU сохраните в виде SKU | nulls_count

# %%
pivot_t = first_group.pivot_table(index='dates',columns='SKU', values='price_per_sku')
plt.figure(figsize=(12,8))
sns.lineplot(data =pivot_t)

# %%
first_group.price_per_sku.isnull().groupby(first_group.SKU).sum().astype(int).reset_index()\
.to_csv('answer_list_2.csv', index=None)

# %%
# 5 Для первой группы данных предложите вариант заполнения пропусков в данных

# %%
first_group['price_per_sku'] = first_group.groupby('SKU').price_per_sku.ffill()

# %%
# 6 Для первой группы данных постройте график эластичности спроса

# %%
plt.figure(figsize=(12,8))

sns.lineplot(x =first_group[first_group.SKU == 32950].num_purchases , y = first_group[first_group.SKU == 32950].price_per_sku)

# %%
plt.figure(figsize=(12,8))

sns.lineplot(x =first_group[first_group.SKU == 78833].num_purchases , y = first_group[first_group.SKU == 78833].price_per_sku)

# %%
# 7 Для второго набора данных постройте график зависимости цены от времени
# Для каждого SKU посчитайте кол-во промо. Результат сохраните в виде SKU | promo_count

# %%
promo_df
# Out:
#     year  week_num    SKU  discount
# 0   2019         1  90611      0.90
# 1   2019         2  10334      0.90
# 2   2019         3  68211      0.90
# 3   2019         4  10334      0.90
# 4   2019         5  72784      0.80
# 5   2019         6  68211      0.90
# 6   2019         7  38767      0.90
# 7   2019         8  83329      0.90
# 8   2019         9  83329      0.95
# 9   2019        10  90611      0.90
# 10  2019        11  57561      0.95
# 11  2019        12  72784      0.90
# 12  2019        13  38767      0.95
# 13  2019        14  57561      0.90
# 14  2019        15  57561      0.80
# 15  2019        16  90611      0.95
# 16  2019        17  43678      0.80
# 17  2019        18  10334      0.80
# 18  2019        19  38767      0.95
# 19  2019        20  17812      0.90
# 20  2019        21  38767      0.95
# 21  2019        22  57561      0.95
# 22  2019        23  10334      0.95
# 23  2019        24  69997      0.80
# 24  2019        25  17812      0.90
# 25  2019        26  17812      0.90
# 26  2019        27  17812      0.95
# 27  2019        28  10334      0.90
# 28  2019        29  90611      0.95
# 29  2019        30  10334      0.80
# 30  2019        31  69997      0.80
# 31  2019        32  57561      0.90
# 32  2019        33  43678      0.90
# 33  2019        34  17812      0.80
# 34  2019        35  90611      0.80
# 35  2019        36  57561      0.90
# 36  2019        37  43678      0.90
# 37  2019        38  57561      0.95
# 38  2019        39  36096      0.90
# 39  2019        40  72784      0.90
# 40  2019        41  64619      0.95
# 41  2019        42  38767      0.95
# 42  2019        43  17812      0.95
# 43  2019        44  43678      0.90
# 44  2019        45  17812      0.90
# 45  2019        46  83329      0.90
# 46  2019        47  90611      0.80
# 47  2019        48  36096      0.95
# 48  2019        49  10334      0.95
# 49  2019        50  10334      0.95
# 50  2019        51  17812      0.90
# 51  2019        52  36096      0.90

# %%
promo_df.shape
# Out:
# (52, 4)

# %%
promo_df.SKU.value_counts().reset_index().rename(columns= {'index':'SKU', 'SKU':'promo_count'})
# Out:
#       SKU  promo_count
# 0   17812            8
# 1   10334            8
# 2   57561            7
# 3   90611            6
# 4   38767            5
# 5   43678            4
# 6   36096            3
# 7   83329            3
# 8   72784            3
# 9   69997            2
# 10  68211            2
# 11  64619            1

# %%
promo_df.SKU.value_counts().reset_index().rename(columns= {'index':'SKU', 'SKU':'promo_count'})\
.to_csv('answer_list_3_1.csv', index=None)

# %%
# 8 Для второго набора данных посчитайте среднее кол-во продаж в период промо и без периода промо
# Результат сохраните в виде SKU | mean_num_purchases_promo |   mean_num_purchases_wo_promo
# Найдите SKU (или группу SKU),  в которых самое сильное отличие средних
# Данный список SKU сохраните отдельно

# %%
promo_df
# Out:
#     year  week_num    SKU  discount
# 0   2019         1  90611      0.90
# 1   2019         2  10334      0.90
# 2   2019         3  68211      0.90
# 3   2019         4  10334      0.90
# 4   2019         5  72784      0.80
# 5   2019         6  68211      0.90
# 6   2019         7  38767      0.90
# 7   2019         8  83329      0.90
# 8   2019         9  83329      0.95
# 9   2019        10  90611      0.90
# 10  2019        11  57561      0.95
# 11  2019        12  72784      0.90
# 12  2019        13  38767      0.95
# 13  2019        14  57561      0.90
# 14  2019        15  57561      0.80
# 15  2019        16  90611      0.95
# 16  2019        17  43678      0.80
# 17  2019        18  10334      0.80
# 18  2019        19  38767      0.95
# 19  2019        20  17812      0.90
# 20  2019        21  38767      0.95
# 21  2019        22  57561      0.95
# 22  2019        23  10334      0.95
# 23  2019        24  69997      0.80
# 24  2019        25  17812      0.90
# 25  2019        26  17812      0.90
# 26  2019        27  17812      0.95
# 27  2019        28  10334      0.90
# 28  2019        29  90611      0.95
# 29  2019        30  10334      0.80
# 30  2019        31  69997      0.80
# 31  2019        32  57561      0.90
# 32  2019        33  43678      0.90
# 33  2019        34  17812      0.80
# 34  2019        35  90611      0.80
# 35  2019        36  57561      0.90
# 36  2019        37  43678      0.90
# 37  2019        38  57561      0.95
# 38  2019        39  36096      0.90
# 39  2019        40  72784      0.90
# 40  2019        41  64619      0.95
# 41  2019        42  38767      0.95
# 42  2019        43  17812      0.95
# 43  2019        44  43678      0.90
# 44  2019        45  17812      0.90
# 45  2019        46  83329      0.90
# 46  2019        47  90611      0.80
# 47  2019        48  36096      0.95
# 48  2019        49  10334      0.95
# 49  2019        50  10334      0.95
# 50  2019        51  17812      0.90
# 51  2019        52  36096      0.90

# %%
second_group.dates = pd.to_datetime(second_group.dates)

# %%
second_group['year'] = second_group.dates.dt.year
second_group['week_num'] = second_group.dates.dt.week
# Out:
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
second_group = second_group.merge(promo_df, how='left', on=['SKU','year','week_num'])

# %%
second_group['is_discount'] = np.where(second_group.discount.isnull(), 0,1)

# %%
second_group[second_group.is_discount==1]
# Out:
#           dates    SKU  price_per_sku  num_purchases  year  week_num  \
# 190  2019-01-07  10334        85.5729             13  2019         2
# 191  2019-01-08  10334        85.5729             11  2019         2
# 192  2019-01-09  10334        85.5729             12  2019         2
# 193  2019-01-10  10334        85.5729             12  2019         2
# 194  2019-01-11  10334        85.5729             14  2019         2
# ...         ...    ...            ...            ...   ...       ...
# 3636 2019-11-18  90611        73.2368              8  2019        47
# 3637 2019-11-19  90611        73.2368              7  2019        47
# 3638 2019-11-20  90611        73.2368              7  2019        47
# 3639 2019-11-23  90611        73.2368              7  2019        47
# 3640 2019-11-24  90611        73.2368              8  2019        47
#
#       discount  is_discount
# 190        0.9            1
# 191        0.9            1
# 192        0.9            1
# 193        0.9            1
# 194        0.9            1
# ...        ...          ...
# 3636       0.8            1
# 3637       0.8            1
# 3638       0.8            1
# 3639       0.8            1
# 3640       0.8            1
#
# [272 rows x 8 columns]

# %%
second_group.groupby('SKU').is_discount.sum()
# Out:
# SKU
# 10334    45
# 17812    46
# 36096    13
# 38767    27
# 43678    22
# 57561    33
# 64619     5
# 68211     9
# 69997    11
# 72784    15
# 83329    15
# 90611    31
# 98255     0
# Name: is_discount, dtype: int64

# %%
second_group.SKU.unique()
# Out:
# array([10334, 17812, 36096, 38767, 43678, 57561, 64619, 68211, 69997,
#        72784, 83329, 90611, 98255])

# %%
second_group.groupby(['SKU','is_discount']).num_purchases.mean()\
.reset_index()\
.pivot_table(index = 'SKU', columns='is_discount', values='num_purchases').reset_index()\
[['SKU', 1,0]]\
.rename(columns={1:'mean_num_purchases_promo', 0:'mean_num_purchases_wo_promo'}).to_csv('answer_list_3_2.csv', index=None)

# %%
second_group.groupby(['SKU','is_discount']).num_purchases.mean()\
.reset_index()\
.pivot_table(index = 'SKU', columns='is_discount', values='num_purchases').reset_index()\
[['SKU', 1,0]]\
.rename(columns={1:'mean_num_purchases_promo', 0:'mean_num_purchases_wo_promo'})
# Out:
# is_discount    SKU  mean_num_purchases_promo  mean_num_purchases_wo_promo
# 0            10334                 11.977778                     9.980050
# 1            17812                  5.934783                     3.613636
# 2            36096                 12.923077                    11.414634
# 3            38767                 10.222222                     9.000000
# 4            43678                 12.090909                     9.448276
# 5            57561                  9.727273                     8.050378
# 6            64619                  5.800000                     4.329897
# 7            68211                 13.111111                    11.459350
# 8            69997                  7.818182                     4.333333
# 9            72784                  9.133333                     6.953782
# 10           83329                 11.866667                     9.416974
# 11           90611                  6.903226                     4.993039
# 12           98255                       NaN                     7.593407

# %%
# 9 Для третьего набора данных постройте график зависимости цены от времени
# Для каждого SKU посчитайте кол-во записей в таблице цен конкурентов ("conc_df.csv")
# Результат сохраните в виде SKU | conc_rows_count

# %%
conc_df
# Out:
#         SKU  year  week_num  ret_net_code  price_per_sku
# 0     84395  2019        18             1      164.69400
# 1     84395  2019        18             2      164.69400
# 2     84395  2019        18             3      134.50010
# 3     84395  2019        22             1      165.19800
# 4     84395  2019        22             2      136.28835
# ...     ...   ...       ...           ...            ...
# 3004  89272  2019        18             2      133.93820
# 3005  89272  2019        18             3      121.76200
# 3006  80308  2019        47             1      115.77984
# 3007  80308  2019        47             2      118.19192
# 3008  80308  2019        47             3      116.98588
#
# [3009 rows x 5 columns]

# %%
conc_df.SKU.value_counts()
# Out:
# 80308    453
# 84395    399
# 89272    396
# 49661    387
# 54404    384
# 11050    384
# 80631    261
# 19632    147
# 60870    105
# 24125     93
# Name: SKU, dtype: int64

# %%
conc_df.groupby('SKU').price_per_sku.count().reset_index()\
.rename(columns={'price_per_sku':'conc_rows_count'})\
.to_csv('answer_list_4_1.csv', index=None)

# %%
conc_df.groupby('SKU').price_per_sku.count().reset_index()\
.rename(columns={'price_per_sku':'conc_rows_count'})\
# Out:
#      SKU  conc_rows_count
# 0  11050              384
# 1  19632              147
# 2  24125               93
# 3  49661              387
# 4  54404              384
# 5  60870              105
# 6  80308              453
# 7  80631              261
# 8  84395              399
# 9  89272              396

# %%
# 10 Для третьего набора данных посчитайте кол-во строк в момент когда цена на SKU была меньше или равна минимальной цене конкурентов
# Результат сохраните в виде SKU | lowest_price_rows_count

# %%
conc_df.groupby(['SKU', 'year', 'week_num']).price_per_sku.agg(['min', 'max']).reset_index()
# Out:
#        SKU  year  week_num        min       max
# 0    11050  2019         1  101.25600  126.5700
# 1    11050  2019         2  103.45370  126.6780
# 2    11050  2019         3  100.35456  125.4432
# 3    11050  2019         4  101.91360  105.0984
# 4    11050  2019         5  101.26848  126.5856
# ..     ...   ...       ...        ...       ...
# 365  89272  2019        47  118.96128  148.7016
# 366  89272  2019        49  119.13600  136.5100
# 367  89272  2019        50  122.61696  153.2712
# 368  89272  2019        51  119.99616  149.9952
# 369  89272  2019        52  120.09024  150.1128
#
# [370 rows x 5 columns]

# %%
aggr_conc = conc_df.groupby(['SKU', 'year', 'week_num']).price_per_sku.agg(['min', 'max']).reset_index()

# %%
third_group.dates = pd.to_datetime(third_group.dates)

# %%
third_group['year'] = third_group.dates.dt.year
third_group['week_num'] = third_group.dates.dt.week
# Out:
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
third_group = third_group.merge(aggr_conc
                  , how='left', on=['SKU', 'year', 'week_num'])

# %%
third_group['lower_than'] = np.where(third_group.price_per_sku <= third_group['min'], 1,0)

# %%
third_group.groupby('SKU').lower_than.sum().reset_index()
# Out:
#      SKU  lower_than
# 0  11050           0
# 1  19632           0
# 2  24125           0
# 3  49661           3
# 4  54404          13
# 5  60870           0
# 6  80308           0
# 7  80631           0
# 8  84395          14
# 9  89272           7

# %%
third_group.groupby('SKU').lower_than.sum().reset_index().to_csv('answer_list_4_2.csv', index=None)

# %%
third_group[third_group.lower_than == 1]
# Out:
#           dates    SKU  price_per_sku  num_purchases  year  week_num      min  \
# 680  2019-07-16  49661        161.960             12  2019        29  161.960
# 681  2019-07-19  49661        161.960             12  2019        29  161.960
# 682  2019-07-20  49661        161.960             12  2019        29  161.960
# 850  2019-03-04  54404         81.124             12  2019        10   81.124
# 851  2019-03-05  54404         81.124             14  2019        10   81.124
# 852  2019-03-06  54404         81.124             12  2019        10   81.124
# 875  2019-04-15  54404         83.504             12  2019        16   83.504
# 876  2019-04-17  54404         83.504             14  2019        16   83.504
# 877  2019-04-19  54404         83.504             12  2019        16   83.504
# 878  2019-04-20  54404         83.504             12  2019        16   83.504
# 879  2019-04-21  54404         83.504             12  2019        16   83.504
# 922  2019-06-24  54404         84.624             12  2019        26   84.624
# 923  2019-06-25  54404         84.624             12  2019        26   84.624
# 924  2019-06-26  54404         84.624             12  2019        26   84.624
# 925  2019-06-27  54404         84.624             12  2019        26   84.624
# 926  2019-06-28  54404         84.624             12  2019        26   84.624
# 2122 2019-01-28  84395        135.488             12  2019         5  135.488
# 2123 2019-01-29  84395        135.488             12  2019         5  135.488
# 2124 2019-01-31  84395        135.488             13  2019         5  135.488
# 2125 2019-02-02  84395        135.488             12  2019         5  135.488
# 2259 2019-08-13  84395        137.056             12  2019        33  137.056
# 2260 2019-08-14  84395        137.056             12  2019        33  137.056
# 2261 2019-08-16  84395        137.056             12  2019        33  137.056
# 2262 2019-08-17  84395        137.056             12  2019        33  137.056
# 2263 2019-08-18  84395        137.056             12  2019        33  137.056
# 2333 2019-12-02  84395        139.800             12  2019        49  139.800
# 2334 2019-12-03  84395        139.800             12  2019        49  139.800
# 2335 2019-12-06  84395        139.800             12  2019        49  139.800
# 2336 2019-12-07  84395        139.800             12  2019        49  139.800
# 2337 2019-12-08  84395        139.800             12  2019        49  139.800
# 2588 2019-03-19  89272        121.615              9  2019        12  121.615
# 2589 2019-03-20  89272        121.615              9  2019        12  121.615
# 2590 2019-03-21  89272        121.615              9  2019        12  121.615
# 2616 2019-04-29  89272        121.762              9  2019        18  121.762
# 2617 2019-05-03  89272        121.762              9  2019        18  121.762
# 2618 2019-05-04  89272        121.762             10  2019        18  121.762
# 2619 2019-05-05  89272        121.762              9  2019        18  121.762
#
#            max  lower_than
# 680   194.3520           1
# 681   194.3520           1
# 682   194.3520           1
# 850    81.1240           1
# 851    81.1240           1
# 852    81.1240           1
# 875   100.2048           1
# 876   100.2048           1
# 877   100.2048           1
# 878   100.2048           1
# 879   100.2048           1
# 922   101.5488           1
# 923   101.5488           1
# 924   101.5488           1
# 925   101.5488           1
# 926   101.5488           1
# 2122  149.0368           1
# 2123  149.0368           1
# 2124  149.0368           1
# 2125  149.0368           1
# 2259  164.4672           1
# 2260  164.4672           1
# 2261  164.4672           1
# 2262  164.4672           1
# 2263  164.4672           1
# 2333  153.7800           1
# 2334  153.7800           1
# 2335  153.7800           1
# 2336  153.7800           1
# 2337  153.7800           1
# 2588  133.7765           1
# 2589  133.7765           1
# 2590  133.7765           1
# 2616  146.1144           1
# 2617  146.1144           1
# 2618  146.1144           1
# 2619  146.1144           1

# %%
# 11 Сделайте предсказание для тестового набора данных

# %%
test = pd.read_csv('test.csv')

# %%
test
# Out:
#           dates    SKU  predicted_price
# 0    2018-12-17  98255        67.478897
# 1    2018-12-21  98255        67.616502
# 2    2018-12-22  98255        67.737991
# 3    2018-12-23  98255        67.438133
# 4    2018-12-24  98255        67.676622
# ..          ...    ...              ...
# 170  2019-12-31  80631        90.016833
# 171  2019-12-31  19632       156.459786
# 172  2019-12-31  84395       137.991576
# 173  2019-12-31  43678       144.127347
# 174  2019-12-31  49661       163.011702
#
# [175 rows x 3 columns]

# %%
test.SKU.value_counts()
# Out:
# 36096    7
# 84395    7
# 80631    7
# 90611    7
# 78833    7
# 57561    7
# 98255    7
# 60870    7
# 89272    7
# 32950    7
# 80308    7
# 19632    7
# 43678    7
# 11050    7
# 17812    7
# 54404    7
# 83329    7
# 68211    7
# 38767    7
# 69997    7
# 64619    7
# 10334    7
# 72784    7
# 24125    7
# 49661    7
# Name: SKU, dtype: int64

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
combine_data = pd.concat([first_group, second_group,third_group]).reset_index(drop=True)

# %%
combine_data.dates = pd.to_datetime(combine_data.dates)

# %%
combine_data[['dates', 'SKU', 'price_per_sku', 'num_purchases']]
# Out:
#           dates    SKU  price_per_sku  num_purchases
# 0    2018-04-20  32950        422.975              3
# 1    2018-04-24  32950        429.275              3
# 2    2018-04-27  32950        435.100              3
# 3    2018-04-30  32950        435.100              1
# 4    2018-05-03  32950        440.950              2
# ...         ...    ...            ...            ...
# 6770 2019-12-17  89272        124.996              5
# 6771 2019-12-18  89272        124.996              6
# 6772 2019-12-19  89272        124.996              5
# 6773 2019-12-20  89272        124.996              6
# 6774 2019-12-21  89272        124.996              6
#
# [6775 rows x 4 columns]

# %%
predictions = {}
for sku in combine_data.SKU.unique():
    train_data= combine_data[combine_data.SKU == sku].price_per_sku.values
    MA = ARIMA(train_data, order=(0,0,20))
    MA_model = MA.fit()
    predictions[sku] = MA_model.predict(start =len(train_data), end= len(train_data) + 7-1)
# Out:
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:868: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   ' zeros.' % warning_description)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:868: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   ' zeros.' % warning_description)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/sgafarov/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
predictions
# Out:
# {32950: array([450.48907878, 452.96397285, 451.07951297, 452.71996516,
#         454.88002432, 451.93117364, 455.05516491]),
#  78833: array([303.8901031 , 303.03839575, 304.72872809, 305.41395636,
#         303.62776796, 303.11981324, 305.14919365]),
#  10334: array([99.8258939 , 98.99996327, 99.03577764, 98.40937222, 97.05586184,
#         97.49278531, 97.27589736]),
#  17812: array([70.04250257, 69.82091544, 70.07833817, 69.94490651, 73.38572113,
#         73.20265923, 73.23294251]),
#  36096: array([131.54139766, 132.53394734, 130.62829909, 131.02980663,
#         130.84862161, 130.12671707, 130.37808203]),
#  38767: array([74.1916389 , 73.47504283, 72.87413351, 72.41068781, 72.52849328,
#         72.72976233, 72.77333677]),
#  43678: array([149.16847831, 147.61728169, 146.89343153, 145.65004675,
#         144.97129137, 144.06958766, 144.12734659]),
#  57561: array([97.97419083, 96.67900163, 95.80703488, 94.85883041, 95.46012769,
#         95.9360359 , 94.74944099]),
#  64619: array([153.12807703, 152.4402493 , 152.4509737 , 151.48909958,
#         149.91929841, 149.74921461, 149.08441504]),
#  68211: array([163.94189785, 165.65581803, 159.90734824, 158.96416762,
#         159.99476414, 153.8956262 , 154.49636075]),
#  69997: array([139.76017538, 135.88480006, 131.95680964, 142.92685729,
#         139.04274291, 142.27481677, 147.60450458]),
#  72784: array([134.77222731, 133.08818553, 132.55017009, 131.70574956,
#         130.93127306, 130.86052822, 130.7702882 ]),
#  83329: array([88.79983575, 88.26891828, 88.19438807, 88.23087251, 87.33303774,
#         87.02064716, 87.00585276]),
#  90611: array([90.01547186, 89.07159321, 89.49879473, 91.48481955, 90.40878544,
#         89.9292412 , 89.4007372 ]),
#  98255: array([67.47889679, 67.61650211, 67.73799101, 67.43813274, 67.67662192,
#         67.4534764 , 67.23843907]),
#  11050: array([110.37944252, 110.06388369, 109.74259125, 109.45567251,
#         109.06589089, 108.7972174 , 108.66510007]),
#  19632: array([156.99210162, 157.83195414, 157.27246027, 157.29739958,
#         157.71954623, 156.86376412, 156.4597863 ]),
#  24125: array([110.14353499, 109.63543924, 108.33348403, 108.6005238 ,
#         108.60129583, 108.79174745, 108.92970082]),
#  49661: array([165.83343589, 165.32689697, 165.39429402, 164.52734519,
#         163.79319978, 163.36288183, 163.01170213]),
#  54404: array([85.63200868, 85.50810479, 85.3434919 , 85.30697295, 85.2523124 ,
#         85.05469304, 84.88468994]),
#  60870: array([117.20740401, 117.69816872, 117.43906423, 117.24815118,
#         116.51535656, 115.75523714, 115.71251288]),
#  80308: array([119.541556  , 119.78827632, 119.39999191, 119.23015712,
#         118.94672938, 118.40583954, 118.10116685]),
#  80631: array([91.42934373, 91.03690325, 90.67435248, 90.52371021, 90.45843331,
#         90.43912085, 90.01683291]),
#  84395: array([140.59475138, 140.09873165, 139.66536872, 139.15053261,
#         138.70193277, 138.24507034, 137.99157609]),
#  89272: array([124.89612921, 124.4674279 , 124.11582759, 123.87460511,
#         124.04992243, 123.42805052, 122.9739922 ])}

# %%
test['predicted_price'] = 0
for sku in test.SKU.unique():
    test.loc[test.SKU == sku, 'predicted_price' ] = predictions[sku]

# %%
test
# Out:
#           dates    SKU  predicted_price
# 0    2018-12-17  98255        67.478897
# 1    2018-12-21  98255        67.616502
# 2    2018-12-22  98255        67.737991
# 3    2018-12-23  98255        67.438133
# 4    2018-12-24  98255        67.676622
# ..          ...    ...              ...
# 170  2019-12-31  80631        90.016833
# 171  2019-12-31  19632       156.459786
# 172  2019-12-31  84395       137.991576
# 173  2019-12-31  43678       144.127347
# 174  2019-12-31  49661       163.011702
#
# [175 rows x 3 columns]

# %%
answers = pd.read_csv('./answers_homework_2/answer_test_set.csv')

# %%
answers = answers.merge(test, how='left', on=['dates', 'SKU'])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(answers.price_per_sku, answers.predicted_price, squared=False)
# Out:
# 4.767151051484594

# %%
answers
# Out:
#           dates    SKU  price_per_sku  predicted_price
# 0    2019-04-10  32950        450.200       450.489079
# 1    2019-04-11  32950        449.925       452.963973
# 2    2019-04-12  32950        447.575       451.079513
# 3    2019-04-13  32950        448.400       452.719965
# 4    2019-04-16  32950        446.525       454.880024
# ..          ...    ...            ...              ...
# 170  2019-12-27  49661        165.978       165.394294
# 171  2019-12-28  49661        165.978       164.527345
# 172  2019-12-29  49661        165.978       163.793200
# 173  2019-12-30  49661        159.205       163.362882
# 174  2019-12-31  49661        159.205       163.011702
#
# [175 rows x 4 columns]
